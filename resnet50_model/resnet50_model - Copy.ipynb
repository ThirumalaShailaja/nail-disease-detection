# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
train_dir = "train"
val_dir = "validation"

# %%
train_dir = r"C:\Users\PC\Desktop\final_project\train"
val_dir   = r"C:\Users\PC\Desktop\final_project\validation"

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

val_gen = ImageDataGenerator(rescale=1./255)

train_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 3744 images belonging to 6 classes.
# Found 116 images belonging to 6 classes.

# %%
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 173s 2us/step

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.1872 - loss: 1.9233 - val_accuracy: 0.1810 - val_loss: 1.8199
# Epoch 2/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.1974 - loss: 1.7916 - val_accuracy: 0.2069 - val_loss: 1.7875
# Epoch 3/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.2086 - loss: 1.7520 - val_accuracy: 0.1810 - val_loss: 1.7671
# Epoch 4/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.2179 - loss: 1.7376 - val_accuracy: 0.1724 - val_loss: 1.7453
# Epoch 5/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.2324 - loss: 1.7301 - val_accuracy: 0.2069 - val_loss: 1.6948
# Epoch 6/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.2377 - loss: 1.7179 - val_accuracy: 0.2328 - val_loss: 1.7040
# Epoch 7/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.2476 - loss: 1.7133 - val_accuracy: 0.2500 - val_loss: 1.6902
# Epoch 8/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.2495 - loss: 1.7038 - val_accuracy: 0.3017 - val_loss: 1.6416
# Epoch 9/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.2540 - loss: 1.6937 - val_accuracy: 0.2672 - val_loss: 1.6623
# Epoch 10/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.2692 - loss: 1.6848 - val_accuracy: 0.3448 - val_loss: 1.6550

# %%
loss, accuracy = model.evaluate(val_generator)
print("ResNet50 Validation Accuracy:", accuracy)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.3448 - loss: 1.6550
# ResNet50 Validation Accuracy: 0.3448275923728943
